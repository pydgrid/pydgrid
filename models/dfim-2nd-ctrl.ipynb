# %%
import numpy as np
import numba
import matplotlib.pyplot as plt
import sympy as sym
plt.style.use('presentation.mplstyle')
# %matplotlib notebook

def d2np(d):
    
    names = []
    numbers = ()
    dtypes = []
    for item in d:
        names += item   
        if type(d[item]) == float:
            numbers += (d[item],)
            dtypes += [(item,float)]
        if type(d[item]) == int:
            numbers += (d[item],)
            dtypes += [(item,int)]
        if type(d[item]) == np.ndarray:
            numbers += (d[item],)
            dtypes += [(item,np.float64,d[item].shape)]
    return np.array([numbers],dtype=dtypes)

# %%
psi_ds,psi_qs,psi_dr,psi_qr = sym.symbols('psi_ds,psi_qs,psi_dr,psi_qr')  
i_ds,i_qs,i_dr,i_qr = sym.symbols('i_ds,i_qs,i_dr,i_qr')  
L_s,L_r,L_m = sym.symbols('L_s,L_r,L_m')  

eq_ds = (L_s+L_m)*i_ds + L_m*i_dr - psi_ds
eq_qs = (L_s+L_m)*i_qs + L_m*i_qr - psi_qs
eq_dr = (L_r+L_m)*i_dr + L_m*i_ds - psi_dr
eq_qr = (L_r+L_m)*i_qr + L_m*i_qs - psi_qr

s = sym.solve([eq_ds,eq_qs,eq_dr,eq_qr],[i_ds,i_qs,i_dr,i_qr])

for item in s:
    print(item, '=', s[item])
# Out:
# i_ds = (-L_m*psi_dr + L_m*psi_ds + L_r*psi_ds)/(L_m*L_r + L_m*L_s + L_r*L_s)
# i_qs = (-L_m*psi_qr + L_m*psi_qs + L_r*psi_qs)/(L_m*L_r + L_m*L_s + L_r*L_s)
# i_dr = (L_m*psi_dr - L_m*psi_ds + L_s*psi_dr)/(L_m*L_r + L_m*L_s + L_r*L_s)
# i_qr = (L_m*psi_qr - L_m*psi_qs + L_s*psi_qr)/(L_m*L_r + L_m*L_s + L_r*L_s)

# %%
# [1] T. Demiray, F. Milano, and G. Andersson, 
# “Dynamic phasor modeling of the doubly-fed induction generator under unbalanced conditions,” 2007 IEEE Lausanne POWERTECH, Proc., no. 2, pp. 1049–1054, 2007.

@numba.jit(nopython=True, cache=True)
def dfim(struct,i):

    x_idx = struct[i]['dfim_idx']
        
    L_m = struct[i]['L_m']
    L_r = struct[i]['L_r']
    L_s = struct[i]['L_s']
    R_r = struct[i]['R_r']
    R_s = struct[i]['R_s']
    
    Dt  = struct[i]['Dt']
    
    psi_ds = struct[i]['psi_ds'] 
    psi_qs = struct[i]['psi_qs']

    psi_dr = float(struct[i]['x'][x_idx+0,0])
    psi_qr = float(struct[i]['x'][x_idx+1,0])

    v_ds = struct[i]['v_ds']
    v_qs = struct[i]['v_qs']
    v_dr = struct[i]['v_dr'] 
    v_qr = struct[i]['v_qr']
    
    omega_r = struct[i]['omega_r']
    omega_s = struct[i]['omega_s']
    
    sigma = (omega_s - omega_r)/omega_s

    i_qr = (L_m*psi_qr - L_m*psi_qs + L_s*psi_qr)/(L_m*L_r + L_m*L_s + L_r*L_s)
    i_qs = (-L_m*psi_qr + L_m*psi_qs + L_r*psi_qs)/(L_m*L_r + L_m*L_s + L_r*L_s)
    i_dr = (L_m*psi_dr - L_m*psi_ds + L_s*psi_dr)/(L_m*L_r + L_m*L_s + L_r*L_s)
    i_ds = (-L_m*psi_dr + L_m*psi_ds + L_r*psi_ds)/(L_m*L_r + L_m*L_s + L_r*L_s)
    
    psi_qs = (R_s*i_ds - v_ds)/omega_s
    psi_ds = (v_qs - R_s*i_qs)/omega_s
    
    dpsi_dr = v_dr - R_r*i_dr + sigma*omega_s*psi_qr
    dpsi_qr = v_qr - R_r*i_qr - sigma*omega_s*psi_dr


    tau_e  = psi_qr*i_dr - psi_dr*i_qr
       
    struct[i]['f'][x_idx+0,0] = float(dpsi_dr)
    struct[i]['f'][x_idx+1,0] = float(dpsi_qr)

    struct[i]['i_ds'] = i_ds
    struct[i]['i_qs'] = i_qs
    struct[i]['i_dr'] = i_dr
    struct[i]['i_qr'] = i_qr
 
    struct[i]['psi_ds'] = psi_ds
    struct[i]['psi_qs'] = psi_qs
    struct[i]['psi_dr'] = psi_dr
    struct[i]['psi_qr'] = psi_qr
    
    struct[i]['tau_e'] = tau_e
    struct[i]['sigma'] = sigma
    
    struct[i]['p_s'] = 3.0/2.0*(v_ds*i_ds + v_qs*i_qs)
    struct[i]['q_s'] = 3.0/2.0*(v_ds*i_qs - v_qs*i_ds)
    
    return tau_e


@numba.jit(nopython=True, cache=True)
def wecs_mech_1(struct,i):

    x_idx = struct[i]['mech_idx']
    omega_t = struct[i]['x'][x_idx,0]  # rad/s
    tau_t   = struct[i]['tau_t']
    tau_r   = struct[i]['tau_r']
       
    J_t  = struct[i]['J_t']
    N_tr = struct[i]['N_tr']
    Dt   = struct[i]['Dt']

    domega_t = 1.0/J_t*(tau_t - N_tr*tau_r)

    omega_r = N_tr*omega_t 
    
    struct[i]['f'][x_idx,0] = domega_t

    struct[i]['omega_r'] = omega_r
    struct[i]['omega_t'] = omega_t

    return omega_t

# %%
@numba.jit(nopython=True, cache=True)
def dfig_ctrl_r_1(struct,i):

    x_idx = struct[i]['ctrl_r']
    xi_ixr = struct[i]['x'][x_idx+0,0]  # rad/s
    xi_iyr = struct[i]['x'][x_idx+1,0]  # rad/s
    
    L_m = struct[i]['L_m']
    L_s = struct[i]['L_s']
    
    i_ds = struct[i]['i_ds']
    i_qs = struct[i]['i_qs']    
    i_dr = struct[i]['i_dr']
    i_qr = struct[i]['i_qr']   
    i_xr_ref = struct[i]['i_xr_ref']
    i_yr_ref = struct[i]['i_yr_ref']  
    
    i_dm = L_s/L_m*i_ds + i_dr
    i_qm = L_s/L_m*i_qs + i_qr
    
    theta_s = np.arctan2(i_qm,i_dm)
    
    struct[i]['theta_s'] = theta_s
    
    i_xr = i_dr*np.cos(theta_s) + i_qr*np.sin(theta_s)
    i_yr = i_qr*np.cos(theta_s) - i_dr*np.sin(theta_s)
    
    error_xr = i_xr_ref - i_xr
    error_yr = i_yr_ref - i_yr
    
    v_xr = 0.1*error_xr + 5.0*xi_ixr
    v_yr = 0.1*error_yr + 5.0*xi_iyr
    
    dxi_ixr = error_xr
    dxi_iyr = error_yr  
    

    v_dr = v_xr*np.cos(theta_s) - v_yr*np.sin(theta_s)
    v_qr = v_xr*np.sin(theta_s) + v_yr*np.cos(theta_s)    

    struct[i]['i_xr'] = i_xr
    struct[i]['i_yr'] = i_yr
    struct[i]['v_dr'] = v_dr
    struct[i]['v_qr'] = v_qr

    struct[i]['f'][x_idx+0,0] = dxi_ixr
    struct[i]['f'][x_idx+1,0] = dxi_iyr
    return theta_s

# %%
Omega_b = 2.0*np.pi*50.0
S_b = 1.0e6
U_b = 690.0
Z_b = U_b**2/S_b
#nu_w =np.linspace(0.1,15,N)
H = 2.0

# H = 0.5*J*Omega_t_n**2/S_b
S_b = 2.0e6
Omega_t_n = 1.5
J_t = 2*H*S_b/Omega_t_n**2


#Z_b = 1.0
#Omega_b = 1.0
d =dict(R_r = 0.01*Z_b,
        R_s = 0.01*Z_b,
        L_r = 0.08*Z_b/Omega_b,
        L_s = 0.1*Z_b/Omega_b,
        L_m = 3.0*Z_b/Omega_b,
        psi_ds = 0.0,
        psi_qs = 0.0,
        p_s = 0.0,
        q_s = 0.0,
        psi_dr = 0.0,
        psi_qr = 0.0,
        i_ds   = 0.0,
        i_qs   = 0.0,
        i_dr   = 0.0,
        i_qr   = 0.0,
        v_ds   = 0.0,
        v_qs   = 0.0,
        v_dr   = 0.0,
        v_qr   = 0.0,
        omega_r   = Omega_b*0.99,
        omega_s   = Omega_b,
        sigma   = 0.0,
        tau_e   = 0.0,        
        x = np.zeros((5,1)),
        f = np.zeros((5,1)),   
        Dt = 0.0,
        J_t = J_t,  
        omega_t = 0.0,  
        tau_t = 0.0,  
        tau_r = 0.0, 
        N_tr = 20.0, 
        dfim_idx = 0,
        mech_idx = 2,
        ctrl_r = 3,
        theta_s = 0.0,
        i_xr = 0.0,
        i_yr = 0.0,
        i_xr_ref = 0.0,
        i_yr_ref = 0.0,
        xi_ixr = 0.0,
        xi_iyr = 0.0,        
        )

struct = d2np(d)
dfim(struct,0)
wecs_mech_1(struct,0)
dfig_ctrl_r_1(struct,0)
# Out:
# 0.0

# %%
struct = d2np(d)

@numba.jit(nopython=True, cache=True)
def f_eval(struct):
    dfim(struct,0)
    wecs_mech_1(struct,0)
    dfig_ctrl_r_1(struct,0)
    return struct[0]['f'][:]

#@numba.jit(nopython=True, cache=True)
def run(struct):  
    struct[0]['x']= np.zeros((5,1))
    struct[0]['v_ds'] = 500.0
    struct[0]['v_qs'] = 0.0
    struct[0]['tau_t'] = 0.0
    struct[0]['x'][2,0] = Omega_b*0.9/struct[0]['N_tr']

    Dt = 1.0e-3
    N_steps = 10000
    Theta_s = np.zeros((N_steps,1))
    P_s = np.zeros((N_steps,1))
    Q_s = np.zeros((N_steps,1))
    I_xr = np.zeros((N_steps,1))
    I_yr = np.zeros((N_steps,1))
    V_dr = np.zeros((N_steps,1))
    V_qr = np.zeros((N_steps,1))
    Tau_e = np.zeros((N_steps,1))
    T     = np.zeros((N_steps,1))
    X = np.zeros((N_steps,5))
    struct[0]['i_xr_ref'] = 1000.0 
    struct[0]['i_yr_ref'] = 0.0 
    for it in range(N_steps):
        t = Dt*float(it)

        # perturbations
        if t>1.0:
            struct[0]['tau_t'] = 100e3
        if t>2.0:
            struct[0]['i_xr_ref'] = 2000.0
        if t>5.0:
            struct[0]['i_yr_ref'] = 0.0
            
        # solver
        f1 = np.copy(f_eval(struct))
        x1 = np.copy(struct[0]['x'][:])
        struct[0]['x'] = np.copy(x1 + Dt*f1)
        struct[0]['x'] = np.copy(x1 + 0.5*Dt*(f1 + f_eval(struct)))
        
        # interconections
        struct[0]['tau_r'] =  struct[0]['tau_e']
        
        # outputs
        Tau_e[it,0] = struct[0]['tau_e']
        X[it,:] = np.copy(struct[0]['x'][:]).T
        T[it,0] = float(t)
        P_s[it,0] = struct[0]['p_s']
        Q_s[it,0] = struct[0]['q_s']
        I_xr[it,0] = struct[0]['i_xr']
        I_yr[it,0] = struct[0]['i_yr']
        V_dr[it,0] = struct[0]['v_dr']
        V_qr[it,0] = struct[0]['v_qr']
        Theta_s[it,0] = struct[0]['theta_s']
    return T,X,Tau_e,P_s,Q_s,Theta_s,I_xr,I_yr,V_dr,V_qr

# %%
T,X,Tau_e,P_s,Q_s,Theta_s,I_xr,I_yr,V_dr,V_qr = run(struct)

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(8, 5), sharex = True)
axes.plot(T,V_dr)
axes.plot(T,V_qr)
fig.savefig('dfim_tau_e.svg', bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="800">
# /home/jmmauricio/bin/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(8, 5), sharex = True)
axes.plot(T,I_xr)
axes.plot(T,I_yr)
fig.savefig('dfim_tau_e.svg', bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="800">
# /home/jmmauricio/bin/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(8, 5), sharex = True)
axes.plot(T,Tau_e)
fig.savefig('dfim_tau_e.svg', bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="800">
# /home/jmmauricio/bin/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(8, 8), sharex = True)
axes[0].plot(T,P_s/1e6, label='$\sf p_s$')
axes[0].plot(T,Q_s/1e6, label='$\sf q_s$')
axes[0].legend()
fig.savefig('dfim_tau_e.svg', bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="800">
# /home/jmmauricio/bin/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(8, 5), sharex = True)
axes.plot(T,X[:,2]*20)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(8, 5), sharex = True)
axes.plot(T,Theta_s)
# Out:
# <img src="data:image/png;base64,..." width="800">
